# %%
##Qiuming Li
import os
import csv
import pandas as pd
root_path=r'C:\Users\49162\Desktop\python\images\camera'
img = os.listdir( root_path )
print(len(img))
train=pd.DataFrame(data=img)
train.to_csv(r'C:\Users\49162\Desktop\python/train1.csv',index=0,header=0)
##output: the number of images in file
# Out:
# 500

# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

#create file list
def createFileList(myDir, format='.png'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList
# load the original image
myFileList = createFileList('C:/Users/49162/Desktop/python/camera')


for file in myFileList:
    print(file)
    img_file = Image.open(file)

    # get original image parameters...
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode

    img_grey = img_file.convert('L')
    value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
    value = value.flatten()
    print(value)
    with open("image_to_csv.csv", 'a') as f:
         writer = csv.writer(f)
         writer.writerow(value)
# Out:
# C:/Users/49162/Desktop/python/camera
# C:/Users/49162/Desktop/python/camera\CameraImage_0001.png
# [182 182 182 ... 182 182 182]
# C:/Users/49162/Desktop/python/camera\CameraImage_0002.png
# [182 182 182 ... 182 182 181]
# C:/Users/49162/Desktop/python/camera\CameraImage_0003.png
# [182 182 182 ... 182 182 181]
# C:/Users/49162/Desktop/python/camera\CameraImage_0004.png
# [182 182 182 ... 182 182 181]
# C:/Users/49162/Desktop/python/camera\CameraImage_0005.png
# [182 182 182 ... 182 182 182]
# C:/Users/49162/Desktop/python/camera\CameraImage_0006.png
# [182 182 182 ... 182 182 182]
# C:/Users/49162/Desktop/python/camera\CameraImage_0007.png
# ...
